# %% [markdown]
# # Hypothesis
#
# * [single-correlation] The number of hurricanes and typhoons are correlated with the surface temperature of each region?

# %% [markdown]
# # import library

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="whitegrid", context="talk")
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')
from scipy import stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.sandbox.stats.multicomp import  multipletests

# %% [markdown]
# # read & clean  datasets

# %%
temp_us_year_df = pd.read_csv("land_temperature_usaonly_year.csv").drop("Unnamed: 0", axis=1)
temp_us_year_df.head()
# Out:
#    year  ave_temp  ave_temp_uncer  month  day
# 0  1768   5.57275        3.757000   10.5  1.0
# 1  1769  10.44650        3.693375    6.5  1.0
# 2  1770       NaN             NaN    6.5  1.0
# 3  1771       NaN             NaN    6.5  1.0
# 4  1772       NaN             NaN    6.5  1.0

# %%
temp_us_year_df.shape
# Out:
# (246, 5)

# %%
hurri_df = pd.read_csv("hurricane_atlantic.csv")
hurri_df.head()
# Out:
#          ID                 Name      Date  Time Event Status Latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   Longitude  Maximum Wind  Minimum Pressure      ...       Low Wind SW  \
# 0     94.8W            80              -999      ...              -999
# 1     95.4W            80              -999      ...              -999
# 2     96.0W            80              -999      ...              -999
# 3     96.5W            80              -999      ...              -999
# 4     96.8W            80              -999      ...              -999
#
#    Low Wind NW  Moderate Wind NE  Moderate Wind SE  Moderate Wind SW  \
# 0         -999              -999              -999              -999
# 1         -999              -999              -999              -999
# 2         -999              -999              -999              -999
# 3         -999              -999              -999              -999
# 4         -999              -999              -999              -999
#
#    Moderate Wind NW  High Wind NE  High Wind SE  High Wind SW  High Wind NW
# 0              -999          -999          -999          -999          -999
# 1              -999          -999          -999          -999          -999
# 2              -999          -999          -999          -999          -999
# 3              -999          -999          -999          -999          -999
# 4              -999          -999          -999          -999          -999
#
# [5 rows x 22 columns]

# %%
hurri_df.shape
# Out:
# (49105, 22)

# %%
hurri_df.columns = list(hurri_df.columns.str.lower().str.replace(" ","_"))
hurri_df.columns
# Out:
# Index(['id', 'name', 'date', 'time', 'event', 'status', 'latitude',
#        'longitude', 'maximum_wind', 'minimum_pressure', 'low_wind_ne',
#        'low_wind_se', 'low_wind_sw', 'low_wind_nw', 'moderate_wind_ne',
#        'moderate_wind_se', 'moderate_wind_sw', 'moderate_wind_nw',
#        'high_wind_ne', 'high_wind_se', 'high_wind_sw', 'high_wind_nw'],
#       dtype='object')

# %%
hurri_df["date"] = hurri_df["date"].astype(str)
hurri_df.dtypes
# Out:
# id                  object
# name                object
# date                object
# time                 int64
# event               object
# status              object
# latitude            object
# longitude           object
# maximum_wind         int64
# minimum_pressure     int64
# low_wind_ne          int64
# low_wind_se          int64
# low_wind_sw          int64
# low_wind_nw          int64
# moderate_wind_ne     int64
# moderate_wind_se     int64
# moderate_wind_sw     int64
# moderate_wind_nw     int64
# high_wind_ne         int64
# high_wind_se         int64
# high_wind_sw         int64
# high_wind_nw         int64
# dtype: object

# %%
hurri_df["year"] = hurri_df["date"].str[:4]
hurri_df["year"] = hurri_df["year"].astype(int)
hurri_df.head()
# Out:
#          id                 name      date  time event status latitude  \
# 0  AL011851              UNNAMED  18510625     0           HU    28.0N
# 1  AL011851              UNNAMED  18510625   600           HU    28.0N
# 2  AL011851              UNNAMED  18510625  1200           HU    28.0N
# 3  AL011851              UNNAMED  18510625  1800           HU    28.1N
# 4  AL011851              UNNAMED  18510625  2100     L     HU    28.2N
#
#   longitude  maximum_wind  minimum_pressure  ...   low_wind_nw  \
# 0     94.8W            80              -999  ...          -999
# 1     95.4W            80              -999  ...          -999
# 2     96.0W            80              -999  ...          -999
# 3     96.5W            80              -999  ...          -999
# 4     96.8W            80              -999  ...          -999
#
#    moderate_wind_ne  moderate_wind_se  moderate_wind_sw  moderate_wind_nw  \
# 0              -999              -999              -999              -999
# 1              -999              -999              -999              -999
# 2              -999              -999              -999              -999
# 3              -999              -999              -999              -999
# 4              -999              -999              -999              -999
#
#    high_wind_ne  high_wind_se  high_wind_sw  high_wind_nw  year
# 0          -999          -999          -999          -999  1851
# 1          -999          -999          -999          -999  1851
# 2          -999          -999          -999          -999  1851
# 3          -999          -999          -999          -999  1851
# 4          -999          -999          -999          -999  1851
#
# [5 rows x 23 columns]

# %% [markdown]
# # compare the number of hurricanes over the period

# %%
hurri_id_gr = hurri_df.groupby(by=["id"])
hurri_id_df = hurri_id_gr.max().reset_index()
hurri_id_df.head()
# Out:
#          id                 name      date  time event status latitude  \
# 0  AL011851              UNNAMED  18510628  2100     L     TS    31.0N
# 1  AL011852              UNNAMED  18520830  1800     L     TS    41.0N
# 2  AL011853              UNNAMED  18530805  1200           TS    32.5N
# 3  AL011854              UNNAMED  18540627  1800     L     TS    28.0N
# 4  AL011855              UNNAMED  18550806  1200           HU    22.2N
#
#   longitude  maximum_wind  minimum_pressure  ...   low_wind_nw  \
# 0     99.8W            80              -999  ...          -999
# 1     88.6W           100               961  ...          -999
# 2     69.0W            50              -999  ...          -999
# 3     98.5W            70              -999  ...          -999
# 4     98.0W            90              -999  ...          -999
#
#    moderate_wind_ne  moderate_wind_se  moderate_wind_sw  moderate_wind_nw  \
# 0              -999              -999              -999              -999
# 1              -999              -999              -999              -999
# 2              -999              -999              -999              -999
# 3              -999              -999              -999              -999
# 4              -999              -999              -999              -999
#
#    high_wind_ne  high_wind_se  high_wind_sw  high_wind_nw  year
# 0          -999          -999          -999          -999  1851
# 1          -999          -999          -999          -999  1852
# 2          -999          -999          -999          -999  1853
# 3          -999          -999          -999          -999  1854
# 4          -999          -999          -999          -999  1855
#
# [5 rows x 23 columns]

# %%
hurri_year_count_df = pd.DataFrame(hurri_id_df["year"].value_counts()).reset_index()
hurri_year_count_df.columns = ["year", "num_of_hurri"]
hurri_year_count_df = hurri_year_count_df.sort_values("year").reset_index()
hurri_year_count_df.head()
# Out:
#    index  year  num_of_hurri
# 0    130  1851             6
# 1    143  1852             5
# 2    104  1853             8
# 3    142  1854             5
# 4    140  1855             5

# %%
sns.jointplot("year", "num_of_hurri", data=hurri_year_count_df, kind="reg", xlim=(1840, 2020), ylim=(0,40), size=7)

# %% [markdown]
# # compare the strength (minimum pressure) of hurricane over the period

# %%
hurri_year_gr = hurri_df.groupby(by="year")
hurri_year_min_df = hurri_year_gr.min().reset_index()
hurri_year_min_df.head()
# Out:
#    year        id                 name      date  time event status latitude  \
# 0  1851  AL011851              UNNAMED  18510625     0           HU    12.0N
# 1  1852  AL011852              UNNAMED  18520819     0           HU    16.1N
# 2  1853  AL011853              UNNAMED  18530805     0           HU    12.0N
# 3  1854  AL011854              UNNAMED  18540625     0           HU    25.0N
# 4  1855  AL011855              UNNAMED  18550806     0           HU    12.0N
#
#   longitude  maximum_wind      ...       low_wind_sw  low_wind_nw  \
# 0    100.0W            40      ...              -999         -999
# 1     58.5W            40      ...              -999         -999
# 2     23.2W            40      ...              -999         -999
# 3    100.0W            40      ...              -999         -999
# 4     24.0W            40      ...              -999         -999
#
#    moderate_wind_ne  moderate_wind_se  moderate_wind_sw  moderate_wind_nw  \
# 0              -999              -999              -999              -999
# 1              -999              -999              -999              -999
# 2              -999              -999              -999              -999
# 3              -999              -999              -999              -999
# 4              -999              -999              -999              -999
#
#    high_wind_ne  high_wind_se  high_wind_sw  high_wind_nw
# 0          -999          -999          -999          -999
# 1          -999          -999          -999          -999
# 2          -999          -999          -999          -999
# 3          -999          -999          -999          -999
# 4          -999          -999          -999          -999
#
# [5 rows x 23 columns]

# %%
sns.jointplot("year", "minimum_pressure", data=hurri_year_min_df, kind="reg", xlim=(1840, 2020))

# %%
hurri_year_min_1991_df = hurri_year_min_df[hurri_year_min_df["year"] > 1991]
sns.jointplot("year", "minimum_pressure", data=hurri_year_min_1991_df, kind="reg", xlim=(1985, 2020))

# %% [markdown]
# # compare the strength (maximum_window) of hurricane over the period

# %%
hurri_year_max_df = hurri_year_gr.max().reset_index()
hurri_year_max_df.head()
# Out:
#    year        id                 name      date  time event status latitude  \
# 0  1851  AL061851              UNNAMED  18511019  2100     L     TS    48.5N
# 1  1852  AL051852              UNNAMED  18521011  2100     L     TS    41.0N
# 2  1853  AL081853              UNNAMED  18531022  1800           TS    48.0N
# 3  1854  AL051854              UNNAMED  18541022  2100     L     TS    40.2N
# 4  1855  AL051855              UNNAMED  18550917  1800     L     TS    54.0N
#
#   longitude  maximum_wind      ...       low_wind_sw  low_wind_nw  \
# 0     99.8W           100      ...              -999         -999
# 1     90.4W           100      ...              -999         -999
# 2     95.0W           130      ...              -999         -999
# 3     98.5W           110      ...              -999         -999
# 4     98.0W           110      ...              -999         -999
#
#    moderate_wind_ne  moderate_wind_se  moderate_wind_sw  moderate_wind_nw  \
# 0              -999              -999              -999              -999
# 1              -999              -999              -999              -999
# 2              -999              -999              -999              -999
# 3              -999              -999              -999              -999
# 4              -999              -999              -999              -999
#
#    high_wind_ne  high_wind_se  high_wind_sw  high_wind_nw
# 0          -999          -999          -999          -999
# 1          -999          -999          -999          -999
# 2          -999          -999          -999          -999
# 3          -999          -999          -999          -999
# 4          -999          -999          -999          -999
#
# [5 rows x 23 columns]

# %%
sns.jointplot("year", "maximum_wind", data=hurri_year_max_df, kind="reg", xlim=(1840, 2020), size=7)

# %% [markdown]
# # merge data of temperature and hurricane

# %%
hurri_year_max_df.shape
# Out:
# (165, 23)

# %%
hurri_year_count_df.shape
# Out:
# (165, 3)

# %%
hurri_count_maxwin_year = pd.concat([hurri_year_count_df, hurri_year_max_df[["year", "maximum_wind"]]], axis=1).drop("index", axis=1)
hurri_count_maxwin_year = hurri_count_maxwin_year.iloc[:,[0,1,3]]
hurri_count_maxwin_year.head()
# Out:
#    year  num_of_hurri  maximum_wind
# 0  1851             6           100
# 1  1852             5           100
# 2  1853             8           130
# 3  1854             5           110
# 4  1855             5           110

# %%
temp_hurri_df = pd.merge(hurri_count_maxwin_year, temp_us_year_df, on="year")
temp_hurri_df.head()
# Out:
#    year  num_of_hurri  maximum_wind  ave_temp  ave_temp_uncer  month  day
# 0  1851             6           100  8.657500        1.526000    6.5  1.0
# 1  1852             5           100  8.183083        1.393750    6.5  1.0
# 2  1853             8           130  8.459917        1.291333    6.5  1.0
# 3  1854             5           110  8.821250        1.484083    6.5  1.0
# 4  1855             5           110  8.459417        1.550417    6.5  1.0

# %% [markdown]
# # expoert data

# %%
temp_hurri_df = temp_hurri_df.drop(["month", "day", "ave_temp_uncer"], axis=1)
temp_hurri_df.head()
# Out:
#    year  num_of_hurri  maximum_wind  ave_temp
# 0  1851             6           100  8.657500
# 1  1852             5           100  8.183083
# 2  1853             8           130  8.459917
# 3  1854             5           110  8.821250
# 4  1855             5           110  8.459417

# %%
temp_hurri_df.describe()
# Out:
#               year  num_of_hurri  maximum_wind    ave_temp
# count   163.000000     163.00000    163.000000  163.000000
# mean   1932.000000      11.00000    114.263804    8.778382
# std      47.198164       5.60313     20.907152    0.553316
# min    1851.000000       1.00000     55.000000    7.669500
# 25%    1891.500000       6.00000    100.000000    8.435250
# 50%    1932.000000      10.00000    115.000000    8.699917
# 75%    1972.500000      14.00000    130.000000    9.026083
# max    2013.000000      30.00000    165.000000   11.297111

# %% [markdown]
# # correlation

# %%
mask = np.ones_like(temp_hurri_df[["num_of_hurri", "maximum_wind", "ave_temp"]].corr(), dtype=np.bool)
mask = np.triu(mask)
mask
# Out:
# array([[ True,  True,  True],
#        [False,  True,  True],
#        [False, False,  True]])

# %%
sns.heatmap(temp_hurri_df[["ave_temp", "num_of_hurri", "maximum_wind"]].corr(), annot=True, mask=mask, cbar=False)

# %%
g = sns.jointplot("ave_temp", "num_of_hurri", data=temp_hurri_df, kind="reg", xlim=(0,12), ylim=(0,40), size=6)
g.set_axis_labels("Averate temperature in the U.S.[celsius degree]", "Number of hurricanes in the year")

# %%
g = sns.jointplot("ave_temp", "maximum_wind", data=temp_hurri_df, kind="reg", xlim=(0,12), size=6)
g.set_axis_labels("Averate temperature in the U.S.[celsius degree]", "Maximus hurricane wind speed in the year[m/s]")
